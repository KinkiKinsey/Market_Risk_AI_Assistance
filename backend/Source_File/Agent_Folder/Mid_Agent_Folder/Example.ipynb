# %%
# CORRECT: You're already in Mid_Agent_Folder
# ==============================================================

import sys
import os

# Add parent directory to path (to access update_pool and Data_Retrieval)
sys.path.insert(0, os.path.abspath('..'))

# Import directly - NO "Mid_Agent_Folder" prefix needed
from Hedge_Fund_Brain import hedgefundbrain

# Now use it
brain, alpha = await hedgefundbrain("DKNG")
# Out:
# 🔄 Generating fresh analysis for DKNG...
# 🧠 Starting SMART Data Pool retrieval for DKNG...
# ...
# ✅ Added Market_Expectation_Agent to warm-up list
# ✅ Added Sector_Analyst_Agent to warm-up list
# ✅ Added Financial_Metrics_Agent to warm-up list
# ✅ Added Macro_Analyst_Agent to warm-up list
# ✅ Added Earning_and_Future_Agent to warm-up list
# ✅ Added Fundamental_Segmentation_Agent to warm-up list
# 🔍 Checking 6 specified agents for update status...
# 🚀 Initializing shared client pool...
# 🤖 Initializing LLM clients...
# 🗄️ Initializing Redis pools...
# 🌐 Initializing HTTP session...
# 🧪 Testing connections...
# ✅ All Redis connections verified
# ⏱️ Initialization time: 1.92 seconds
#
# 📊 Update Status Summary:
# ...
# market_expectation: ✅ FRESH
#    Last update: 2025-10-21T20:56:44.323746
# financial_metrics: ✅ FRESH
#    Last update: 2025-10-21T16:55:48.886370
# earnings_future: ✅ FRESH
#    Last update: 2025-10-21T20:56:17.194738
# macro_analysis: ✅ FRESH
# ...
